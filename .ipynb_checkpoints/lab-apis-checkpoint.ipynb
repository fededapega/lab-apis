# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
#CLIENT_ID = "<introduce your client id>"
#CLIENT_SECRET = "<introduce your client secret>"

# %%
#CLIENT_ID = "4109b2d9f5014671863bb2df1d1fbdd3"
#CLIENT_SECRET = "5cb719fae80c4191a9c0b288f51bfe50"

# %%
# If you havent done so, install the spotipy wrapper
# !pip install spotipy

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="1abeec6d049249e78b669b56772fa727",
                                                           client_secret="74d797420722454aa606c0bf2ada8c22"))

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
results = sp.search(q='Lady Gaga', limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
# ...

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys() # Let's check the values
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50'

# %%
results["tracks"]["items"] #items (actual tracks)
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
# ...

# %%
results["tracks"]["limit"]#Limit we have chosen
# Out:
# 50

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=50&limit=50'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["total"] # Number of matches
# Out:
# 1000

# %% [markdown]
# ## Exploring the tracks

# %%
results["tracks"]["items"][0] # Explore the first song
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# Lady Gaga

# %%
# Track ID

results["tracks"]["items"][0]["id"]
# Out:
# '0SiywuOBRcynK0uKGWdCnn'

# %%
# Track name
results["tracks"]["items"][0]["name"]
# Out:
# 'Bad Romance'

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"]
# Out:
# 87

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:0SiywuOBRcynK0uKGWdCnn'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist's name. The method requires a `q` parameter, which is your query (in this case, the artist's name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated 'artists' field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist's details, you can extract the 'id' field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist's ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist's ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You'll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you're confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %%
#1
my_artists = ["Metallica", "Amelie Lens", "Blink 182"]

# %%
def get_top_tracks(my_artists):
    top_tracks_list = []

    for artist in my_artists:
        # Search for the artist
        results = sp.search(q=artist, type='artist')

        # Check if there are any results
        if results['artists']['items']:
            artist_id = results['artists']['items'][0]['id']

            # Get the top tracks for the artist
            top_tracks = sp.artist_top_tracks(artist_id)['tracks']

            # Sort the tracks by popularity
            sorted_tracks = sorted(top_tracks, key=lambda x: x['popularity'], reverse=True)

            # Take the top 5 tracks
            top_5_tracks = sorted_tracks[:5]

            # Append to top_tracks_list including artist name
            for track in top_5_tracks:
                top_tracks_list.append({'artist': artist, 'track': track['name'], 'popularity': track['popularity']})

    return top_tracks_list

my_artists = ["Metallica", "Amelie Lens", "Blink 182"]
result = get_top_tracks(my_artists)
print(result)
# Out:
# [{'artist': 'Metallica', 'track': 'Enter Sandman (Remastered)', 'popularity': 78}, {'artist': 'Metallica', 'track': 'Master of Puppets (Remastered)', 'popularity': 74}, {'artist': 'Metallica', 'track': 'For Whom The Bell Tolls (Remastered)', 'popularity': 74}, {'artist': 'Metallica', 'track': 'Nothing Else Matters (Remastered)', 'popularity': 73}, {'artist': 'Metallica', 'track': 'One (Remastered)', 'popularity': 73}, {'artist': 'Amelie Lens', 'track': 'You and Me', 'popularity': 66}, {'artist': 'Amelie Lens', 'track': 'Feel It', 'popularity': 62}, {'artist': 'Amelie Lens', 'track': 'In Silence', 'popularity': 56}, {'artist': 'Amelie Lens', 'track': 'Follow', 'popularity': 52}, {'artist': 'Amelie Lens', 'track': "Raver's heart", 'popularity': 48}, {'artist': 'Blink 182', 'track': 'All The Small Things', 'popularity': 86}, {'artist': 'Blink 182', 'track': "What's My Age Again?", 'popularity': 82}, {'artist': 'Blink 182', 'track': 'I Miss You', 'popularity': 79}, {'artist': 'Blink 182'
# ...

# %%
#ressults = sp.search(q='Metallica', limit=1)
#ressults["tracks"].keys()

# %%
#ressults

# %%
#metallica_id = results["tracks"]["items"][0]["album"]["artists"][0]["id"]
#metallica_id '1HY2Jd0NmPuamShAr6KMms'

# %%
my_artists = ["Metallica", "Amelie Lens", "Blink 182"]

# %%
artist_ids = []

for each in my_artists:
    ressults = sp.search(q=each, limit=1)
    artist_id = ressults["tracks"]["items"][0]["album"]["artists"][0]["id"]
    artist_ids.append(artist_id)
artist_ids
# Out:
# ['2ye2Wgw4gimLv2eAKyk1NB', '5Ho1vKl1Uz8bJlk4vbmvmf', '6FBDaR13swtiWwGhX1WQsP']

# %%
results = sp.search(q='Metallica', limit=1)
metallica_id = results["tracks"]["items"][0]["album"]["artists"][0]["id"]
metallica_id
# Out:
# '2ye2Wgw4gimLv2eAKyk1NB'

# %%
results = sp.search(q='Amelie Lens', limit=1)
amelie_id = results["tracks"]["items"][0]["album"]["artists"][0]["id"]
amelie_id
# Out:
# '5Ho1vKl1Uz8bJlk4vbmvmf'

# %%
results = sp.search(q='Blink 182', limit=1)
maceo_id = results["tracks"]["items"][0]["album"]["artists"][0]["id"]
maceo_id
# Out:
# '6FBDaR13swtiWwGhX1WQsP'

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="1abeec6d049249e78b669b56772fa727",
                                                           client_secret="74d797420722454aa606c0bf2ada8c22"))

artist_ids = ['2ye2Wgw4gimLv2eAKyk1NB', '5Ho1vKl1Uz8bJlk4vbmvmf', '6FBDaR13swtiWwGhX1WQsP']

related_artists_list = []

for artist_id in artist_ids:
    try:
        # Fetch related artists using the artist ID
        related_artists_response = sp.artist_related_artists(artist_id)
        
        # Extract only the first 5 related artist names
        related_artists_names = [artist['name'] for artist in related_artists_response['artists'][:5]]
        
        # Append the list of related artist names to the result
        related_artists_list.append(related_artists_names)
    except Exception as e:
        # Handle exceptions (e.g., print an error message)
        print(f"Error fetching related artists for artist ID {artist_id}: {e}")
        related_artists_list.append([])  # Append an empty list to indicate an issue

related_artists_list
# Out:
# [['Megadeth', 'Pantera', 'Iron Maiden', 'Slayer', 'Black Sabbath'],
#  ['ANNA',
#   'Charlotte de Witte',
#   'Enrico Sangiuliano',
#   'Adam Beyer',
#   'Nina Kraviz'],
#  ['Sum 41',
#   'Good Charlotte',
#   'Jimmy Eat World',
#   'Yellowcard',
#   'Bowling For Soup']]

# %%
heavy_metal = related_artists_list[0]
techno = related_artists_list[1]
punk = related_artists_list[2]

# %%
heavy_metal
# Out:
# ['Megadeth', 'Pantera', 'Iron Maiden', 'Slayer', 'Black Sabbath']

# %%
techno
# Out:
# ['ANNA',
#  'Charlotte de Witte',
#  'Enrico Sangiuliano',
#  'Adam Beyer',
#  'Nina Kraviz']

# %%
punk
# Out:
# ['Sum 41',
#  'Good Charlotte',
#  'Jimmy Eat World',
#  'Yellowcard',
#  'Bowling For Soup']

# %%
heavymetal_toptracks = get_top_tracks(heavy_metal)
techno_toptracks = get_top_tracks(techno)
punk_toptracks = get_top_tracks(punk)

# %%
heavymetal_toptracks
# Out:
# [{'artist': 'Megadeth',
#   'track': 'Symphony Of Destruction - Remastered 2012',
#   'popularity': 71},
#  {'artist': 'Megadeth',
#   'track': 'Holy Wars...The Punishment Due - 2004 Remix',
#   'popularity': 71},
#  {'artist': 'Megadeth',
#   'track': 'A Tout Le Monde - Remastered 2004',
#   'popularity': 70},
#  {'artist': 'Megadeth',
#   'track': 'Tornado Of Souls - 2004 Remix',
#   'popularity': 69},
#  {'artist': 'Megadeth', 'track': 'Peace Sells - Remastered', 'popularity': 67},
#  {'artist': 'Pantera', 'track': 'Walk', 'popularity': 78},
#  {'artist': 'Pantera', 'track': 'Cowboys from Hell', 'popularity': 75},
#  {'artist': 'Pantera', 'track': 'Cemetery Gates', 'popularity': 70},
#  {'artist': 'Pantera', 'track': 'Domination', 'popularity': 70},
#  {'artist': 'Pantera', 'track': "I'm Broken", 'popularity': 68},
#  {'artist': 'Iron Maiden',
#   'track': 'The Trooper (2015 Remaster)',
#   'popularity': 66},
#  {'artist': 'Iron Maiden',
# ...

# %%
techno_toptracks
# Out:
# [{'artist': 'ANNA',
#   'track': 'EVERYDAY (feat. Shiva, ANNA, Geolier)',
#   'popularity': 79},
#  {'artist': 'ANNA', 'track': 'Petit Fou Fou (feat. ANNA)', 'popularity': 78},
#  {'artist': 'ANNA', 'track': 'VETRI NERI', 'popularity': 76},
#  {'artist': 'ANNA',
#   'track': 'ANELLI E COLLANE (feat. ANNA)',
#   'popularity': 74},
#  {'artist': 'ANNA', 'track': 'Ciao Bella', 'popularity': 74},
#  {'artist': 'Charlotte de Witte',
#   'track': 'The Age Of Love (Charlotte de Witte & Enrico Sangiuliano Remix)',
#   'popularity': 71},
#  {'artist': 'Charlotte de Witte', 'track': 'Pria', 'popularity': 62},
#  {'artist': 'Charlotte de Witte', 'track': 'Reflection', 'popularity': 62},
#  {'artist': 'Charlotte de Witte',
#   'track': 'Overdrive - Edit',
#   'popularity': 59},
#  {'artist': 'Charlotte de Witte',
#   'track': 'Hold That Sucker Down (Mixed) - Charlotte de Witte Trance Remix',
#   'popularity': 57},
#  {'artist': 'Enrico Sangiuliano',
# ...

# %%
punk_toptracks
# Out:
# [{'artist': 'Sum 41', 'track': 'In Too Deep', 'popularity': 78},
#  {'artist': 'Sum 41', 'track': 'Fat Lip', 'popularity': 78},
#  {'artist': 'Sum 41', 'track': 'Pieces', 'popularity': 73},
#  {'artist': 'Sum 41', 'track': 'Still Waiting', 'popularity': 69},
#  {'artist': 'Sum 41', 'track': 'War', 'popularity': 69},
#  {'artist': 'Good Charlotte', 'track': 'The Anthem', 'popularity': 77},
#  {'artist': 'Good Charlotte',
#   'track': 'Lifestyles of the Rich & Famous',
#   'popularity': 71},
#  {'artist': 'Good Charlotte', 'track': 'I Just Wanna Live', 'popularity': 65},
#  {'artist': 'Good Charlotte',
#   'track': "I Don't Wanna Be In Love (Dance Floor Anthem)",
#   'popularity': 64},
#  {'artist': 'Good Charlotte', 'track': 'Girls & Boys', 'popularity': 64},
#  {'artist': 'Jimmy Eat World', 'track': 'The Middle', 'popularity': 85},
#  {'artist': 'Jimmy Eat World', 'track': 'Sweetness', 'popularity': 72},
#  {'artist': 'Jimmy Eat World', 'track': 'Bleed American', 'popularity': 68},
# ...

# %%
metallica_toptracks = result[0:5]
metallica_toptracks
# Out:
# [{'artist': 'Metallica',
#   'track': 'Enter Sandman (Remastered)',
#   'popularity': 78},
#  {'artist': 'Metallica',
#   'track': 'Master of Puppets (Remastered)',
#   'popularity': 74},
#  {'artist': 'Metallica',
#   'track': 'For Whom The Bell Tolls (Remastered)',
#   'popularity': 74},
#  {'artist': 'Metallica',
#   'track': 'Nothing Else Matters (Remastered)',
#   'popularity': 73},
#  {'artist': 'Metallica', 'track': 'One (Remastered)', 'popularity': 73}]

# %%
amelielens_toptracks = result[5:10]
amelielens_toptracks
# Out:
# [{'artist': 'Amelie Lens', 'track': 'You and Me', 'popularity': 66},
#  {'artist': 'Amelie Lens', 'track': 'Feel It', 'popularity': 62},
#  {'artist': 'Amelie Lens', 'track': 'In Silence', 'popularity': 56},
#  {'artist': 'Amelie Lens', 'track': 'Follow', 'popularity': 52},
#  {'artist': 'Amelie Lens', 'track': "Raver's heart", 'popularity': 48}]

# %%
blink182_toptracks = result[10:15]
blink182_toptracks
# Out:
# [{'artist': 'Blink 182', 'track': 'All The Small Things', 'popularity': 86},
#  {'artist': 'Blink 182', 'track': "What's My Age Again?", 'popularity': 82},
#  {'artist': 'Blink 182', 'track': 'I Miss You', 'popularity': 79},
#  {'artist': 'Blink 182', 'track': 'First Date', 'popularity': 78},
#  {'artist': 'Blink 182', 'track': "Adam's Song", 'popularity': 75}]

# %%
# heavymetal_toptracks
# techno_toptracks
# punk_toptracks
# metallica_toptracks
# amelielens_toptracks
# blink182_toptracks

# %%
import pandas as pd

metal = metallica_toptracks + heavymetal_toptracks

metal_df = pd.DataFrame(metal, columns=['artist', 'track', 'popularity'])
metal_df
# Out:
#            artist                                        track  popularity
# 0       Metallica                   Enter Sandman (Remastered)          78
# 1       Metallica               Master of Puppets (Remastered)          74
# 2       Metallica         For Whom The Bell Tolls (Remastered)          74
# 3       Metallica            Nothing Else Matters (Remastered)          73
# 4       Metallica                             One (Remastered)          73
# 5        Megadeth    Symphony Of Destruction - Remastered 2012          71
# 6        Megadeth  Holy Wars...The Punishment Due - 2004 Remix          71
# 7        Megadeth            A Tout Le Monde - Remastered 2004          70
# 8        Megadeth                Tornado Of Souls - 2004 Remix          69
# 9        Megadeth                     Peace Sells - Remastered          67
# 10        Pantera                                         Walk          78
# ...

# %%
punkx = blink182_toptracks + punk_toptracks
punk_df = pd.DataFrame(punkx,columns=['artist', 'track', 'popularity'])
punk_df
# Out:
#               artist                                             track  \
# 0          Blink 182                              All The Small Things
# 1          Blink 182                              What's My Age Again?
# 2          Blink 182                                        I Miss You
# 3          Blink 182                                        First Date
# 4          Blink 182                                       Adam's Song
# 5             Sum 41                                       In Too Deep
# 6             Sum 41                                           Fat Lip
# 7             Sum 41                                            Pieces
# 8             Sum 41                                     Still Waiting
# 9             Sum 41                                               War
# 10    Good Charlotte                                        The Anthem
# 11    Good Charlotte                   Lifestyles of the Rich & Famous
# ...

# %%
technox = amelielens_toptracks + techno_toptracks
techno_df = pd.DataFrame(technox, columns=['artist', 'track', 'popularity'])
techno_df
# Out:
#                 artist                                              track  \
# 0          Amelie Lens                                         You and Me
# 1          Amelie Lens                                            Feel It
# 2          Amelie Lens                                         In Silence
# 3          Amelie Lens                                             Follow
# 4          Amelie Lens                                      Raver's heart
# 5                 ANNA              EVERYDAY (feat. Shiva, ANNA, Geolier)
# 6                 ANNA                         Petit Fou Fou (feat. ANNA)
# 7                 ANNA                                         VETRI NERI
# 8                 ANNA                      ANELLI E COLLANE (feat. ANNA)
# 9                 ANNA                                         Ciao Bella
# 10  Charlotte de Witte  The Age Of Love (Charlotte de Witte & Enrico S...
# 11  Charlotte de Witte                                               Pria
# ...

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="1abeec6d049249e78b669b56772fa727",
                                                           client_secret="74d797420722454aa606c0bf2ada8c22"))

sp.featured_playlists() # We get a playlist id of a playlist we like
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Os grandes hits reunidos numa playlist única! Foto: Teddy Swims.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0rV7skaITBo'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0rV7skaITBo',
#     'id': '37i9dQZF1DX0rV7skaITBo',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000263d5158756bde59f50c64f03',
#       'width': None}],
#     'name': 'Hot Hits Portugal',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
# ...

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
playlist = sp.playlist(playlist_id)

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
# Out:
# Hits acústicos
# Relájate con tus canciones favoritas en versión acústica / Descontrai com versões acústicas das tuas músicas preferidas.

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name
# Out:
# Take Me Home, Country Roads
# Time After Time
# True Colours
# Days Like This
# Stay With Me - Live From Spotify Berlin
# September Song - Guitar Acoustic
# Cold Heart - Acoustic
# Sunday Morning - Acoustic
# Too Good At Goodbyes - Acoustic
# Wild Love - Acoustic
# La Vie En Rose
# You Are My Sunshine
# Collide - Acoustic Version
# I'm Not the Only One - Live from Spotify, London
# Baby One More Time - Recorded at Spotify Studios New York City
# Better Together
# Stand By Me
# If You Ever Wanna Be In Love - James Bay Spotify Session 2015
# No One - Acoustic
# When You Love Someone - Acoustic
# Naked - Acoustic Version
# Shape of You - Acoustic
# Dreams - Piano Version
# Let It Go - James Bay Spotify Session 2015
# What About Us - Acoustic
# Something Just Like This - Acoustic
# Perfect - Acoustic
# Set Fire to the Rain - Cover
# Ain't Nobody (Loves Me Better) - Acoustic
# Little Talks
# Blinding Lights
# Issues - Acoustic
# Rockabye - Acoustic Version
# 1973 - Acoustic
# Rather Be
# ...

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['Lana Del Rey', 'Iron & Wine', 'Tom Odell', 'Dermot Kennedy', 'Angus & Julia Stone', 'JP Cooper', 'Elton John', 'Dua Lipa', 'Maroon 5', 'Sam Smith', 'James Bay', 'Daniela Andrade', 'Jasmine Thompson', 'Howie Day', 'Ed Sheeran', 'Us The Duo', 'Florence + The Machine', 'Alicia Keys', 'James TW', 'James Arthur', 'Lissie', 'Thomas Daniel', 'Missy & Blonde', 'Julia Ross', 'Noah Guthrie', 'Julia Sheer', 'Jon D', 'Ouvindo', 'Julia Michaels', 'The Mayries', 'James Blunt', 'Niall Horan', 'Lauv', 'Freedom Fry', 'Charlie Puth', 'Kacey Musgraves', 'Tom Speight', 'Lydia Clowes', 'Eddie Berman', 'Calum Scott', 'Aaron Krause', 'Liza Anne', 'Kygo', 'Conrad Sewell', 'Colin & Caroline', 'Twin Bandit', 'Joshua Hyslop', 'The Wind and The Wave', 'Run River North', 'John Mayer', 'Lotte Kestner', 'Sixpence None The Richer', 'Taken By Trees', 'Jessie J', 'Megan Davies', 'Keelan Donovan', 'John Legend', 'Jonas Blue', 'William Singe', 'Halloran & Kate', 'Sara Farell', 'Passenger', 'Joy Williams', 'Lily Allen
# ...

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
# Your answer here

le_featured = sp.featured_playlists()
le_featured
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Os grandes hits reunidos numa playlist única! Foto: Teddy Swims.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0rV7skaITBo'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0rV7skaITBo',
#     'id': '37i9dQZF1DX0rV7skaITBo',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000263d5158756bde59f50c64f03',
#       'width': None}],
#     'name': 'Hot Hits Portugal',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
# ...

# %%
le_featured.keys()
# Out:
# dict_keys(['message', 'playlists'])

# %%
le_featured['playlists'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
le_featured['playlists']['items'][0]['id']
# Out:
# '37i9dQZF1DX0rV7skaITBo'

# %%
len(le_featured['playlists']['items'])
# Out:
# 20

# %%
playlist_info = [{'id': item['id'], 'name': item['name']}
                 for item in le_featured['playlists']['items']]

# %%
len(playlist_info)
# Out:
# 20

# %%
#https://developer.spotify.com/documentation/web-api/reference/get-featured-playlists

#there's no popularity object, so how to pull the top? will pull the first 5

# %%
top_playlists = playlist_info[0:5]

# %%
top_playlists
# Out:
# [{'id': '37i9dQZF1DX0rV7skaITBo', 'name': 'Hot Hits Portugal'},
#  {'id': '37i9dQZF1DX0FOF1IUWK1W', 'name': 'Top Brasil'},
#  {'id': '37i9dQZF1DWTkIwO2HDifB', 'name': 'Funk Hits'},
#  {'id': '37i9dQZF1DX6ViL9RcFABv', 'name': 'Pop PT'},
#  {'id': '37i9dQZF1DXcBWIGoYBM5M', 'name': 'Today’s Top Hits'}]

# %%
#Deep Dive:

#Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#Fetch and display its name, description, and total track count.

# %%
playlist_id = '37i9dQZF1DX0rV7skaITBo'
playlist_info0 = le_featured['playlists']['items']

for item in playlist_info0:
    if item['id'] == playlist_id:
        name = item['name']
        description = item['description']
        total_tracks = item['tracks']['total']
        break

print(name)
print(description)
print(total_tracks)
# Out:
# Hot Hits Portugal
# Os grandes hits reunidos numa playlist única! Foto: Teddy Swims.
# 50

# %%
#Extract and display the names of the first 10 tracks in the chosen playlist.

# %%
top10tracksofportu = []
tracksofportu = sp.playlist_tracks(playlist_id)
for track in tracksofportu['items']:
    top10tracksofportu.append(track['track']['name'])

# %%
tracksofportu['items'][0]
# Out:
# {'added_at': '2024-01-29T08:35:09Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7crp1tZcefnjT5RuL6WZQ0'},
#      'href': 'https://api.spotify.com/v1/artists/7crp1tZcefnjT5RuL6WZQ0',
#      'id': '7crp1tZcefnjT5RuL6WZQ0',
#      'name': 'Slow J',
#      'type': 'artist',
#      'uri': 'spotify:artist:7crp1tZcefnjT5RuL6WZQ0'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
# ...

# %%
#insidetracksofportu = tracksofportu['items'][0]
#for each in insidetracksofportu['track']['album']['artists']:
#top10artists = []
#for artist in tracksofportu['items']:
    #top10artists.append(artist['track']['album']['artists']['name'])

# %%
top10 = top10tracksofportu[0:10]
top10
# Out:
# ['Tata',
#  'Carro (feat. Dillaz)',
#  'Poesia Acústica 15',
#  'Tenho Que Me Decidir',
#  'Lose Control',
#  'POCPOC',
#  'Si No Estás',
#  'MONACO',
#  'Cheiro de Mato',
#  'UH LA LA LA']

# %%
top10artists = []
for artist in tracksofportu['items']:
    
    top10artists.append(artist['track']['album']['artists'][0]['name'])

# %%
top10artist = top10artists[0:10]
top10artist
# Out:
# ['Slow J',
#  'Bárbara Bandeira',
#  'Various Artists',
#  'MC PH',
#  'Teddy Swims',
#  'PEDRO SAMPAIO',
#  'iñigo quintero',
#  'Bad Bunny',
#  'Gabi Saiury',
#  'LON3R JOHNY']

# %% [markdown]
# Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
# For example: {"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}

# %%
#my artists = top10artist
#my songs = top10

pairs = zip(top10,top10artist)
mydict = dict(pairs)
mydict
# Out:
# {'Tata': 'Slow J',
#  'Carro (feat. Dillaz)': 'Bárbara Bandeira',
#  'Poesia Acústica 15': 'Various Artists',
#  'Tenho Que Me Decidir': 'MC PH',
#  'Lose Control': 'Teddy Swims',
#  'POCPOC': 'PEDRO SAMPAIO',
#  'Si No Estás': 'iñigo quintero',
#  'MONACO': 'Bad Bunny',
#  'Cheiro de Mato': 'Gabi Saiury',
#  'UH LA LA LA': 'LON3R JOHNY'}

# %%
#mynewdict = {"Song:"+ song : {"Artist": artist} for song, artist in pairs}

# %%
#mynewdict

# %% [markdown]
# # Hello Lera, how can I get this:
#
# {Song: 'Tata': Artist: 'Slow J',
#  Song: 'Carro (feat. Dillaz)': Artist: 'Bárbara Bandeira....}

# %% [markdown]
# # instead of:
#
# {'Tata': 'Slow J',
#  'Carro (feat. Dillaz)': 'Bárbara Bandeira'...}
